# %%
from IPython.display import Image, display
from app.agent import build_graph_for

# %%
g = build_graph_for(1)
png_bytes = g.get_graph().draw_png() 
display(Image(data=png_bytes))

# %%
import IPython

IPython.display.Image

Image(g.get_graph().draw_mermaid_png())
